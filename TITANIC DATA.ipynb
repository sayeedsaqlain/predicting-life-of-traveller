# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r'C:\Users\vinaykumar\Desktop\Untitled Folder\titanic_data.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
a=df.drop(df.columns[[0,3,5,6,7,8,10]],axis=1)
a.head()
# Out:
#    Survived  Pclass     Sex     Fare Embarked
# 0         0       3    male   7.2500        S
# 1         1       1  female  71.2833        C
# 2         1       3  female   7.9250        S
# 3         1       1  female  53.1000        S
# 4         0       3    male   8.0500        S

# %%
a.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Fare        0
# Embarked    2
# dtype: int64

# %%
h=a.dropna()

# %%
h.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Fare        0
# Embarked    0
# dtype: int64

# %%
mymap={'male':0,'female':1,}
e=h.applymap(lambda s:mymap.get(s) if s in mymap else s)
e.head()
# Out:
#    Survived  Pclass  Sex     Fare Embarked
# 0         0       3    0   7.2500        S
# 1         1       1    1  71.2833        C
# 2         1       3    1   7.9250        S
# 3         1       1    1  53.1000        S
# 4         0       3    0   8.0500        S

# %%
e.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex           int64
# Fare        float64
# Embarked     object
# dtype: object

# %%
mymap={'S':0,'C':1,'Q':2}
f=e.applymap(lambda s:mymap.get(s) if s in mymap else s)
f.head()
# Out:
#    Survived  Pclass  Sex     Fare  Embarked
# 0         0       3    0   7.2500         0
# 1         1       1    1  71.2833         1
# 2         1       3    1   7.9250         0
# 3         1       1    1  53.1000         0
# 4         0       3    0   8.0500         0

# %%
f.corr()
# Out:
#           Survived    Pclass       Sex      Fare  Embarked
# Survived  1.000000 -0.335549  0.541585  0.255290  0.108669
# Pclass   -0.335549  1.000000 -0.127741 -0.548193  0.043835
# Sex       0.541585 -0.127741  1.000000  0.179958  0.118593
# Fare      0.255290 -0.548193  0.179958  1.000000  0.063462
# Embarked  0.108669  0.043835  0.118593  0.063462  1.000000

# %%
f
# Out:
#      Survived  Pclass  Sex      Fare  Embarked
# 0           0       3    0    7.2500         0
# 1           1       1    1   71.2833         1
# 2           1       3    1    7.9250         0
# 3           1       1    1   53.1000         0
# 4           0       3    0    8.0500         0
# 5           0       3    0    8.4583         2
# 6           0       1    0   51.8625         0
# 7           0       3    0   21.0750         0
# 8           1       3    1   11.1333         0
# 9           1       2    1   30.0708         1
# 10          1       3    1   16.7000         0
# 11          1       1    1   26.5500         0
# 12          0       3    0    8.0500         0
# 13          0       3    0   31.2750         0
# 14          0       3    1    7.8542         0
# 15          1       2    1   16.0000         0
# 16          0       3    0   29.1250         2
# 17          1       2    0   13.0000         0
# 18          0       3    1   18.0000         0
# ...

# %%
y=f["Survived"]
x=f.loc[:,"Pclass":"Embarked"]

# %%
t=pd.DataFrame(x)

# %%
t
# Out:
#      Pclass  Sex      Fare  Embarked
# 0         3    0    7.2500         0
# 1         1    1   71.2833         1
# 2         3    1    7.9250         0
# 3         1    1   53.1000         0
# 4         3    0    8.0500         0
# 5         3    0    8.4583         2
# 6         1    0   51.8625         0
# 7         3    0   21.0750         0
# 8         3    1   11.1333         0
# 9         2    1   30.0708         1
# 10        3    1   16.7000         0
# 11        1    1   26.5500         0
# 12        3    0    8.0500         0
# 13        3    0   31.2750         0
# 14        3    1    7.8542         0
# 15        2    1   16.0000         0
# 16        3    0   29.1250         2
# 17        2    0   13.0000         0
# 18        3    1   18.0000         0
# 19        3    1    7.2250         1
# 20        2    0   26.0000         0
# 21        2    0   13.0000         0
# 22        3    1    8.0292         2
# 23        1    0   35.5000         0
# ...

# %%
t.dropna()
# Out:
#      Pclass  Sex      Fare  Embarked
# 0         3    0    7.2500         0
# 1         1    1   71.2833         1
# 2         3    1    7.9250         0
# 3         1    1   53.1000         0
# 4         3    0    8.0500         0
# 5         3    0    8.4583         2
# 6         1    0   51.8625         0
# 7         3    0   21.0750         0
# 8         3    1   11.1333         0
# 9         2    1   30.0708         1
# 10        3    1   16.7000         0
# 11        1    1   26.5500         0
# 12        3    0    8.0500         0
# 13        3    0   31.2750         0
# 14        3    1    7.8542         0
# 15        2    1   16.0000         0
# 16        3    0   29.1250         2
# 17        2    0   13.0000         0
# 18        3    1   18.0000         0
# 19        3    1    7.2250         1
# 20        2    0   26.0000         0
# 21        2    0   13.0000         0
# 22        3    1    8.0292         2
# 23        1    0   35.5000         0
# ...

# %%
t.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Fare        0
# Embarked    0
# dtype: int64

# %%
t.dtypes
# Out:
# Pclass        int64
# Sex           int64
# Fare        float64
# Embarked      int64
# dtype: object

# %%
model=KNeighborsClassifier()

# %%
for i in range(1,6,2):
    model=KNeighborsClassifier(n_neighbors=i);
    x_t,x_te,y_t,y_te=train_test_split(x,y,train_size=0.9,random_state=1)
    model.fit(x_t,y_t)
    print 'Train','k=',i,'\t->\t',accuracy_score(y_t,model.predict(x_t))
    print 'Test','k=',i,'\t->\t',accuracy_score(y_te,model.predict(x_te))
# Out:
# Train k= 1 	->	0.8975
# Test k= 1 	->	0.8089887640449438
# Train k= 3 	->	0.85375
# Test k= 3 	->	0.797752808988764
# Train k= 5 	->	0.83375
# Test k= 5 	->	0.8202247191011236
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
model.score(x_te,y_te)
# Out:
# 0.8202247191011236
